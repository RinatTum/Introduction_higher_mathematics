# %% [raw]
# 4. Задание (в программе):
#  Постройте на одном графике две кривые y(x) для функции двух переменных y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 20, 120)
k_1 = 1
k_2 = 5
y_1 = np.cos(k_1 * x)
y_2 = np.cos(k_2 * x)
plt.plot(x, y_1, x, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f1b0757af40>,
#  <matplotlib.lines.Line2D at 0x7f1b0757afa0>]
